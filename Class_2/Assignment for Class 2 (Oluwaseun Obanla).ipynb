# %% [markdown]
# ### 1. Write a program to calculate the length of a string

# %%
x = "Dunsin has a brave heart"

x
# Out:
# 'Dunsin has a brave heart'

# %%
len(x) #This will calculate the length of the string
# Out:
# 24

# %% [markdown]
# ### 2. Write a program to get a string made of the first 2 and last 2 characters of a given string

# %%
x[:2] + x[-2:] #Using string slicing and concantenation
# Out:
# 'Durt'

# %% [markdown]
# ### 3. Write a python program to add "ing" at the end of any given string .

# %%
x = "Dusin likes fight"

x
# Out:
# 'Dusin likes fight'

# %%
x + "ing"
# Out:
# 'Dusin likes fighting'

# %% [markdown]
# ### 4. Write a python program to remove the nth index character from a string.

# %%
x.strip("D")
# Out:
# 'usin likes fight'

# %% [markdown]
# ## Use the working_with_tables_homework.csv file to answer the following questions.

# %%
import pandas as pd

data = pd.read_csv("working_with_tables_homework.txt")

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com

# %% [markdown]
# ### 5. Create a new column that generates the initials of the sales representatives. The initials must be in the form:
#
# - The first letter of their first name + . + The first letter of their last name. For example: Olanrewaju Kazeem would be: O.K

# %%
data ["Firstname"].str[0]
# Out:
# 0    O
# 1    C
# 2    O
# 3    O
# 4    A
# 5    K
# 6    O
# 7    T
# 8    T
# 9    N
# Name: Firstname, dtype: object

# %%
data ["Lastname"].str[0]
# Out:
# 0    K
# 1    E
# 2    A
# 3    B
# 4    I
# 5    F
# 6    D
# 7    S
# 8    K
# 9    D
# Name: Lastname, dtype: object

# %%
data ["Initials"] = data ["Firstname"].str[0] + ["."] + data ["Lastname"].str[0]

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials
# 0      O.K
# 1      C.E
# 2      O.A
# 3      O.B
# 4      A.I
# 5      K.F
# 6      O.D
# 7      T.S
# 8      T.K
# 9      N.D

# %% [markdown]
# ### 6. If the commision that each sales representative is entitled to is 15% of the revenue generated, create a new column that generates this commission column.

# %%
data ["Revenue"] = data ["sales"] - data ["cost"]

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials  Revenue
# 0      O.K     4000
# 1      C.E    10600
# 2      O.A    17000
# 3      O.B     6000
# 4      A.I    17650
# 5      K.F    11017
# ...

# %%
data ["Commission"] = data ["Revenue"] * 0.15

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials  Revenue  Commission
# 0      O.K     4000      600.00
# 1      C.E    10600     1590.00
# 2      O.A    17000     2550.00
# 3      O.B     6000      900.00
# ...

# %% [markdown]
# ### 7. Suppose we are interested in knowing the character length of each peron's fullname for the new app the company is creating, create a new column containing the character length for each sales representative.

# %%
data ["Fullname"] = data ["Firstname"] + [" "] + data ["Lastname"]

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials  Revenue  Commission             Fullname
# 0      O.K     4000      600.00    Olanrewaju Kazeem
# 1      C.E    10600     1590.00       Chibuzo Ekenne
# ...

# %%
data ["Characterlength"] = len (data ["Fullname"])

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials  Revenue  Commission             Fullname   Username  \
# 0      O.K     4000      600.00    Olanrewaju Kazeem  Olan_Kaze
# ...

# %% [markdown]
# ### 8. In the new app to be created, the first 4 characters of the employee's full name is to be used as user name along with the first 4 characters of the employee's last name. These two pairs of 4 characters must be separated by an underscore.
#     For example, Olanrewaju Kazeem will have a username of: Olan_Kaze
#     - Create a new column that contains this new username.

# %%
data ["Username"] = data ["Fullname"].str[:4] + ["_"] + data ["Lastname"].str[:4]

data
# Out:
#     Firstname   Lastname   age   sales   cost                      email  \
# 0  Olanrewaju     Kazeem  [24]   15000  11000     olankaz248@outlook.com
# 1     Chibuzo     Ekenne  [30]   25800  15200   chiman_ekeneks@yahoo.com
# 2  Onyinyechi       Amos  [22]   45000  28000       onyiamos22@gmail.com
# 3     Orlando      Bloom  [25]   28000  22000       earlyman01@ymail.com
# 4        Alex      Iwobi  [34]   36500  18850     iwo.alex_007@gmail.com
# 5       Kachi      Felix  [50]   44235  33218  felix_kach@protonmail.com
# 6     Olujare       Dada  [28]   27500  25800    olu59_dada@zohomail.com
# 7      Tomiwa    Sogaolu  [42]   50509  34850   tommySolu@icloudmail.com
# 8   Timilehin  Kupolokun  [49]   88390  76001     timikupo11@outlook.com
# 9       Nnena    Dickson  [39]  122200  85900           nene33@gmail.com
#
#   Initials  Revenue  Commission             Fullname   Username  \
# 0      O.K     4000      600.00    Olanrewaju Kazeem  Olan_Kaze
# ...
